# %% [markdown]
# # Roman-Coronagraph Reference/Science Target Pitch and Solar Observability
#
# This notebook builds on the example notebook from https://github.com/roman-corgi/roman_pointing to allow the user to query any science target and determine which reference stars are available to observe in tandem at any given time of the year. You will need to install roman-pointing to your environment to utilize this notebook. You will also need astropy, astroquery, matplotlib, and numpy (which would be installed be default with roman-pointing) along with pandas

# %%
from roman_pointing.roman_pointing import calcRomanAngles, getL2Positions, getSunPositions
import astropy.units as u
from astropy.time import Time
from astroquery.simbad import Simbad
from astropy.coordinates import (
    SkyCoord,
    Distance,
    get_body_barycentric,
    BarycentricMeanEcliptic,
)
import matplotlib.pyplot as plt
import numpy as np
import pandas
import time
from matplotlib.lines import Line2D
from matplotlib.gridspec import GridSpec
from matplotlib.patches import Patch,Rectangle
from astropy.coordinates import HeliocentricTrueEcliptic
from astropy.coordinates import HeliocentricMeanEcliptic
from astropy.coordinates import Galactic
from astropy.coordinates import ICRS
from astroquery.jplhorizons import Horizons

# %% [markdown]
# ## Helper functions to query Simbad for science target data and to load a pandas dataframe of the reference stars

# %% [markdown]
# This function will query Simbad for the necessary information (ra, dec, pmra, pmdec, parallax, and radial velocity) for the science target. Reference star information is loaded in separately from a supplied catalog.

# %%
def LoadExistingDatabase(filename='RefStar_S10_2025-05-20.csv'):
    #Input a database csv filename and load it with pandas
    loadedCSV = pandas.read_csv(filename)
    return loadedCSV

# %%
def queryTap_byname(name):
    #Perform a Simbad TAP query to obtain information about a target. 'name' must be a simbad-recognizable identifier
    example_base = """SELECT TOP 1 oid, main_id, ids, ra, dec, coo_err_maj, coo_err_min, coo_err_angle, coo_qual, coo_bibcode,
                        pmra, pmdec, pm_err_maj, pm_err_min, pm_err_angle, pm_qual, pm_bibcode, plx_value, plx_err, plx_qual, plx_bibcode,
                        rvz_radvel, rvz_err, rvz_bibcode,
                        otype, otypes, sp_type, sp_bibcode, 
                        U, B, V, G, R, I, J, H, K, u_, g_, r_, i_, z_
                        FROM basic JOIN alltypes ON basic.oid = alltypes.oidref JOIN allfluxes ON basic.oid = allfluxes.oidref
                        JOIN ident ON basic.oid = ident.oidref JOIN ids ON basic.oid = ids.oidref
                        WHERE id = '{insertname}'
                        AND ra IS NOT NULL
                        AND dec IS NOT NULL;"""
    example = example_base.format(insertname=name)

    queryresult = Simbad.query_tap(example)

    time.sleep(1) #Sleeps are used to make sure CDS doesn't blacklist your IP for being a robot

    return queryresult

# %% [markdown]
# ## Master Function to Plot Reference Star Observability
# To determine solar and pitch angles for all of the reference stars to compare to the science target, it's easier to pre-load reference star information from a file rather than submit a Simbad query for each reference star. This function allows you to input any Simbad-known science target, select either all valid or a subset of reference stars (indicated by ranks 'A', 'B', and 'C' with 'A' being most likely to be usable), a delta_pitch angle restriction, and options for saving figures and csvs. It will also calculate visibility/observability against the visibility of the galactic bulge, which Roman/WFI will observe near continuously when it is visible. The generated plots are:
#
# The upper left plot shows the solar angle as a function of days of the year from 20270101, with the thick dashed blue line representing the "Science" target. Disallowed regions (solar/planet keepout) are shaded black. Visibility of the galactic bulge is roughly shown with the dashed thick red line.
#
# The upper center plot calculates the pitch angle as a function of days of the year for both "science" target, reference stars, and galactic bulge under the assumption of an October 2026 launch.
#
# The upper right plot calculates the difference in pitch angle between science and each reference star, with the absolute minimum (among any science-reference pair combination) is the thicker blue line.
#
# The lower left plot combines the information from the upper left plot and the upper center plot to determine the days of the year when a science target and a given reference star are both observable in general (solar angle restriction) and when the delta pitch is within the user set condition (default, 5 degrees).
#
# The lower center plot squashes the information in the lower left plot to find the absolute minimum delta pitch between science and any given reference star for any day (and would still be generally observable). The red points are the blue points where overlapping with the galactic bulge is removed.
#
# Finally, the lower right plot shows the number of available reference stars for the "science" target on any given day, again with red points considering when the galactic bulge is not visible.

# %%
def PitchfromRefCatalog_Mod(sciname,ranks=['A','B','C'],delpitch=5.0,save=False,savedir='.'):
    ###Query information about a science target from Simbad and determine which reference stars from a selected list of reference stars are observable with the science target considering the
    ###solar keepout and delta_pitch restriction
    ###Inputs:
    ###sciname: Simbad-known star identifier for the science target
    ###ranks: List of strings representing reference star ranks to include. Can only accept 'A','B','C', and 'F'
    ###delpitch: Delta pitch restriction in degrees
    ###save: If true, save the generated figure and valid delta pitch and dates for each reference star to a csv
    ###savedir: where to save the generated figure and csv
    RefStars = LoadExistingDatabase('RefStar_S10_amendGrade.csv')

    RefStarsOriginal = RefStars.iloc[:40] #This is a hardcoded value to only load in the nominal 40 reference stars currently being considered
    for rank in np.arange(len(ranks)):
        RefStarsRank = RefStarsOriginal.iloc[np.where(RefStarsOriginal["st_psfgrade"]==ranks[rank])]
        if RefStarsRank.shape[0] == 0:
            raise Exception("No Rank "+ranks[rank]+" stars in loaded table")
        if rank == 0:
            RefStarsNominal = RefStarsRank
        elif rank > 0:
            RefStarsNominal = pandas.concat([RefStarsNominal,RefStarsRank])
    RefStarsNominal = RefStarsNominal.reset_index(drop=True)
    #Create a new dataframe that will track days of the year and delta pitch angle calculations
    print('Selected reference stars:')
    print(RefStarsNominal["main_id"].values)
    pitchDFcolumns = RefStarsNominal["main_id"].values
    pitchDFcolumns = np.insert(pitchDFcolumns,0,'Day')

    t_str = ["2027-01-01T00:00:00.0"]
    t0 = Time(t_str, format="isot", scale="utc")
    ts = t0 + np.arange(365)*u.d
    dt = f"{int((ts[1] - ts[0]).to_value(u.d))}d"

    #Query Horizons for the ephemeris of the Roman Space Telescope
    obj = Horizons(id='-211', location="@0", epochs={"start":ts[0].value, "stop":ts[-1].value, "step":dt}) #Roman location
    roman_vectors_table = obj.vectors()
    roman_pos = np.vstack([roman_vectors_table[l].data.filled() for l in ["x", "y", "z"]])*u.AU


    #Create a pandas dataframe where the columns are delta pitch calculations for each reference star. Each row is day of the year
    delta_pitchDF = pandas.DataFrame(columns=pitchDFcolumns)


    

    time2027 = range(len(ts))
    delta_pitchDF["Day"] = time2027

    #Determine science properties
    result = queryTap_byname(sciname)
    #Need to replace nan values with placeholder values that assume 0 pm, 0 rvz, very small parallax
    result_pandas = result.to_pandas()
    if np.isnan(result_pandas.loc[0,"plx_value"]) == True:
        result_pandas.loc[0,"plx_value"] = 0.0001
    if np.isnan(result_pandas.loc[0,"pmra"]) == True:
        result_pandas.loc[0,"pmra"] = 0.0
    if np.isnan(result_pandas.loc[0,"pmdec"]) == True:
        result_pandas.loc[0,"pmdec"] = 0.0
    if np.isnan(result_pandas.loc[0,"rvz_radvel"]) == True:
        result_pandas.loc[0,"rvz_radvel"] = 0.0

    target = SkyCoord(
                        result_pandas.loc[0,"ra"],
                        result_pandas.loc[0,"dec"],
                        unit=(u.deg, u.deg),
                        frame="icrs",
                        distance=Distance(parallax=result_pandas.loc[0,"plx_value"] * u.mas),
                        pm_ra_cosdec=result_pandas.loc[0,"pmra"] * u.mas/u.yr,
                        pm_dec=result_pandas.loc[0,"pmdec"] * u.mas/u.yr,
                        radial_velocity=result_pandas.loc[0,"rvz_radvel"] * u.km/u.s,
                        equinox="J2000",
                        obstime="J2000",
                        ).transform_to(BarycentricMeanEcliptic)

    #Check against Galactic Bulge scheduling
    bulgetarget = queryTap_byname('[GKM98] S0-17') #This is a representative target at the center of the Galactic bulge

    sun_ang_targ, yaw_targ, pitch_targ, B_C_I_targ = calcRomanAngles(target, ts, roman_pos) #Calculate angles for science target

    bulge_pandas = bulgetarget.to_pandas()
    if np.isnan(bulge_pandas.loc[0,"plx_value"]) == True:
        bulge_pandas.loc[0,"plx_value"] = 0.0001
    if np.isnan(bulge_pandas.loc[0,"pmra"]) == True:
        bulge_pandas.loc[0,"pmra"] = 0.0
    if np.isnan(bulge_pandas.loc[0,"pmdec"]) == True:
        bulge_pandas.loc[0,"pmdec"] = 0.0
    if np.isnan(bulge_pandas.loc[0,"rvz_radvel"]) == True:
        bulge_pandas.loc[0,"rvz_radvel"] = 0.0

    target_bulge = SkyCoord(
                        bulge_pandas.loc[0,"ra"],
                        bulge_pandas.loc[0,"dec"],
                        unit=(u.deg, u.deg),
                        frame="icrs",
                        distance=Distance(parallax=bulge_pandas.loc[0,"plx_value"] * u.mas),
                        pm_ra_cosdec=bulge_pandas.loc[0,"pmra"] * u.mas/u.yr,
                        pm_dec=bulge_pandas.loc[0,"pmdec"] * u.mas/u.yr,
                        radial_velocity=bulge_pandas.loc[0,"rvz_radvel"] * u.km/u.s,
                        equinox="J2000",
                        obstime="J2000",
                        ).transform_to(BarycentricMeanEcliptic)

    sun_ang_bulge, yaw_bulge, pitch_bulge, B_C_I_bulge = calcRomanAngles(target_bulge, ts, roman_pos) #Calculate angles for Galactic bulge

    layout = '''
            ABC
            DEF
            '''

    fig1, axs = plt.subplot_mosaic(layout, layout='constrained',figsize=(14,6))

    fig1.suptitle(sciname,fontsize=18)

    axs['A'].set_xlabel(f"Time after {ts[0].value} (days)",fontsize=10)
    axs['A'].set_ylabel("Solar Angle (deg)",fontsize=14)
    axs['A'].set_xlim([np.min(time2027),np.max(time2027)])
    axs['A'].set_ylim([0,180])
    axs['B'].set_xlabel(f"Time after {ts[0].value} (days)",fontsize=10)
    axs['B'].set_ylabel("Pitch Angle (deg)",fontsize=14)
    axs['B'].set_xlim([np.min(time2027),np.max(time2027)])
    axs['C'].set_xlabel(f"Time after {ts[0].value} (days)",fontsize=10)
    axs['C'].set_ylabel(r"Absolute $\Delta$Pitch (deg)",fontsize=14)
    axs['C'].set_xlim([np.min(time2027),np.max(time2027)])
    axs['D'].set_xlabel(f"Time after {ts[0].value} (days)",fontsize=10)
    axs['D'].set_ylabel(r"Absolute $\Delta$Pitch (deg)",fontsize=14)
    axs['D'].set_xlim([np.min(time2027),np.max(time2027)])
    sun_angs = [] #all solar angles from all ref stars
    pitch_angs = [] #all pitch angles from all ref stars
    abs_pitch_angs = [] #all delta pitch angles for all ref stars+target


    obslengths = np.array([]) #number of days of observability for each reference star/target pair
    obslengths_wbulge = np.array([]) #number of days of observability for each reference star/target pair excluding bulge days

    abs_pitch_actualobs = [] #delta pitch angles when both ref and target observable and also delta pitch < 5 for all ref/target pairs
    abs_pitch_actualobs_wbulge = [] #delta pitch angles when both ref and target observable and also delta pitch < 5 for all ref/target pairs w bulge taken into account
    obsdates_actualobs = [] #days when the above is satisfied for all ref/target pairs
    obsdates_actualobs_wbulge = [] #days when ref and target are observable within delta pitch for all all ref/target pairs and bulge is not visible

    lines4legend = []


    for i in np.arange(RefStarsNominal.shape[0]):
        #Create skycoord object
        #Use Gaia RA and if it doesn't exist use simbad RA
        if np.isnan(RefStarsNominal.loc[i,"ra2016"]) == False and np.isnan(RefStarsNominal.loc[i,"pmra2016"]) == False and np.isnan(RefStarsNominal.loc[i,"st_radv2016"]) == False and np.isnan(RefStarsNominal.loc[i,"sy_plx2016"]) == False:
            ra = RefStarsNominal.loc[i,"ra2016"]
            ra_unit = u.deg
            dec = RefStarsNominal.loc[i,"dec2016"]
            dec_unit = u.deg
            pmra = RefStarsNominal.loc[i,"pmra2016"]
            pmra_unit = u.mas/u.yr
            pmdec = RefStarsNominal.loc[i,"pmdec2016"]
            pmdec_unit = u.mas/u.yr
            plx = RefStarsNominal.loc[i,"sy_plx2016"]
            plx_unit = u.mas
            radv = RefStarsNominal.loc[i,"st_radv2016"]
            radv_unit = u.km/u.s
            obstime = "J2016"
        else:
            ra = RefStarsNominal.loc[i,"ra"]
            ra_unit = u.deg
            dec = RefStarsNominal.loc[i,"dec"]
            dec_unit = u.deg
            pmra = RefStarsNominal.loc[i,"sy_pmra"]
            pmra_unit = u.mas/u.yr
            pmdec = RefStarsNominal.loc[i,"sy_pmdec"]
            pmdec_unit = u.mas/u.yr
            plx = RefStarsNominal.loc[i,"sy_plx"]
            plx_unit = u.mas
            radv = RefStarsNominal.loc[i,"st_radv"]
            radv_unit = u.km/u.s
            obstime = "J2000"

        ref = SkyCoord(
                    ra,
                    dec,
                    unit=(ra_unit, dec_unit),
                    frame="icrs",
                    distance=Distance(parallax=plx * plx_unit),
                    pm_ra_cosdec=pmra * pmra_unit,
                    pm_dec=pmdec * pmdec_unit,
                    radial_velocity=radv * radv_unit,
                    equinox=obstime,
                    obstime=obstime,
                    ).transform_to(BarycentricMeanEcliptic)

        sun_ang_ref, yaw_ref, pitch_ref, B_C_I_targ = calcRomanAngles(ref, ts, roman_pos)
        fulldeltapitch = np.abs(pitch_targ - pitch_ref).to(u.deg)
        sun_angs.append(sun_ang_ref)
        pitch_angs.append(pitch_ref)
        abs_pitch_angs.append(fulldeltapitch)
        axs['A'].plot(range(len(ts)), sun_ang_ref.to(u.deg),label=RefStarsNominal.loc[i,"main_id"])
        axs['B'].plot(range(len(ts)), pitch_ref.to(u.deg),label=RefStarsNominal.loc[i,"main_id"])
        line2add, = axs['C'].plot(range(len(ts)),fulldeltapitch,label=RefStarsNominal.loc[i,"main_id"])
        lines4legend.append(line2add)

        actualobsdates = np.array([])
        obsdeltapitch = np.array([])
        obsdeltapitch_wbulge = np.array([])
        nonbulgedays = np.array([])
        for j in time2027:
            if sun_ang_targ.to(u.deg)[j] <=126*u.deg and sun_ang_targ.to(u.deg)[j] >= 54*u.deg and sun_ang_ref.to(u.deg)[j] <=126*u.deg and sun_ang_ref.to(u.deg)[j] >= 54*u.deg and fulldeltapitch[j] <= delpitch*u.deg:
                actualobsdates = np.append(actualobsdates,j)
                obsdeltapitch = np.append(obsdeltapitch,fulldeltapitch[j].value)

                if sun_ang_bulge.to(u.deg)[j]<54*u.deg or sun_ang_bulge.to(u.deg)[j]>126*u.deg:
                    nonbulgedays = np.append(nonbulgedays,j)
                    obsdeltapitch_wbulge = np.append(obsdeltapitch_wbulge,fulldeltapitch[j].value)
                else:
                    nonbulgedays = np.append(nonbulgedays,np.nan)
                    obsdeltapitch_wbulge = np.append(obsdeltapitch_wbulge,np.nan)
            else:
                actualobsdates = np.append(actualobsdates,np.nan)
                obsdeltapitch = np.append(obsdeltapitch,np.nan)
                obsdeltapitch_wbulge = np.append(obsdeltapitch_wbulge,np.nan)
                nonbulgedays = np.append(nonbulgedays,np.nan)
        obslengths = np.append(obslengths,len(actualobsdates[np.where(np.isnan(actualobsdates)==False)]))
        obslengths_wbulge = np.append(obslengths_wbulge,len(nonbulgedays[np.where(np.isnan(nonbulgedays)==False)]))
        abs_pitch_actualobs.append(obsdeltapitch)
        abs_pitch_actualobs_wbulge.append(obsdeltapitch_wbulge)
        obsdates_actualobs.append(actualobsdates)
        obsdates_actualobs_wbulge.append(nonbulgedays)
        print(len(actualobsdates[np.where(np.isnan(actualobsdates)==False)]),"days of general and < "+str(delpitch)+" degree Delta pitch angle observability with "+RefStarsNominal.loc[i,"main_id"])
        print(len(nonbulgedays[np.where(np.isnan(nonbulgedays)==False)]),"days of general and < "+str(delpitch)+" degree Delta pitch angle observability with "+RefStarsNominal.loc[i,"main_id"]+" and not conflicting with bulge")
        RefStarsNominal.loc[i,"ObsDays"] = len(actualobsdates[np.where(np.isnan(actualobsdates)==False)])
        RefStarsNominal.loc[i,"ObsDays_wBulge"] = len(nonbulgedays[np.where(np.isnan(nonbulgedays)==False)])
        axs['D'].plot(actualobsdates, obsdeltapitch*u.deg,marker='o')
        axs['D'].plot(nonbulgedays, obsdeltapitch_wbulge*u.deg,marker='^')
        delta_pitchDF[pitchDFcolumns[i+1]] = obsdeltapitch
    fullstackpitch = np.array(abs_pitch_angs)
    absminpitch = np.nanmin(fullstackpitch,axis=0)
    fullstackobs_pitch = np.array(abs_pitch_actualobs)
    fullstackobs_pitch_wbulge = np.array(abs_pitch_actualobs_wbulge)
    fullstackobs_pitch_days = np.array(obsdates_actualobs)
    fullstackobs_pitch_days_wbulge = np.array(obsdates_actualobs_wbulge)
    obs_absminpitch = np.nanmin(fullstackobs_pitch,axis=0)
    obs_absminpitch_wbulge = np.nanmin(fullstackobs_pitch_wbulge,axis=0)
    print(len(obs_absminpitch[np.where(np.isnan(obs_absminpitch)==False)]),"days of general and < "+str(delpitch)+" degree Delta pitch angle observability with any available ref")
    print(len(obs_absminpitch_wbulge[np.where(np.isnan(obs_absminpitch_wbulge)==False)]),"days of general and < "+str(delpitch)+" degree Delta pitch angle observability with any available ref and not during bulge")

    #Determine number of reference stars each day that satisfy <5 degree delta pitch and target/ref pair generally observable
    net_stars_obs = np.array([])
    net_stars_obs_wbulge = np.array([])
    for i in np.arange(len(time2027)):
        dayslice = fullstackobs_pitch[:,i]
        dayslice_wbulge = fullstackobs_pitch_wbulge[:,i]
        numstars = len(dayslice[np.where(np.isnan(dayslice)==False)])
        numstars_wbulge = len(dayslice_wbulge[np.where(np.isnan(dayslice_wbulge)==False)])
        net_stars_obs = np.append(net_stars_obs,numstars)
        net_stars_obs_wbulge = np.append(net_stars_obs_wbulge,numstars_wbulge)

    axs['A'].plot(range(len(ts)), sun_ang_targ.to(u.deg),'b',label="Sci:"+sciname,linewidth=5,linestyle='--')
    axs['B'].plot(range(len(ts)), pitch_targ.to(u.deg),'b',label="Sci:"+sciname,linewidth=5,linestyle='--')
    axs['A'].plot(range(len(ts)), sun_ang_bulge.to(u.deg),'r',label="Galactic Bulge",linewidth=5,linestyle='-.')
    axs['B'].plot(range(len(ts)), pitch_bulge.to(u.deg),'r',label="Galactic Bulge",linewidth=5,linestyle='-.')

    axs['A'].plot([0, len(ts)-1], [54] * 2, "k--")
    axs['A'].plot([0, len(ts)-1], [126] * 2, "k--")
    axs['A'].fill_between(
                        [0, len(ts)-1],
                        [54] * 2,
                        [0] * 2,
                        #hatch="/",
                        color="k",
                        #alpha=0.75,
                        edgecolor="k",
                        linewidth=0)
    axs['A'].fill_between(
                        [0, len(ts)-1],
                        [126] * 2,
                        [180] * 2,
                        #hatch="\\",
                        color="k",
                        #alpha=0.75,
                        edgecolor="k",
                        linewidth=0)

    

    absminline, = axs['C'].plot(time2027,absminpitch,linewidth=5,color='b',label='Abs. Min.')
    #Add a legend if you don't have too many reference stars
    
    axs['C'].legend(handles=[absminline],fontsize=10)
    if RefStarsNominal.shape[0] < 20:
        fig1.legend(handles=lines4legend,loc='outside center right',fontsize=10)


    axs['E'].plot(np.nanmin(np.array(obsdates_actualobs),axis=0),np.nanmin(np.array(abs_pitch_actualobs),axis=0),marker='o',color='b')
    axs['E'].plot(np.nanmin(np.array(obsdates_actualobs_wbulge),axis=0),np.nanmin(np.array(abs_pitch_actualobs_wbulge),axis=0),marker='^',color='r')
    axs['E'].set_xlabel(f"Time after {ts[0].value} (days)",fontsize=10)
    axs['E'].set_ylabel(r"Abs. Min. $\Delta$ Pitch (deg)",fontsize=14)
    axs['E'].set_xlim([np.min(time2027),np.max(time2027)])
    axs['F'].scatter(time2027,net_stars_obs,color='b')
    axs['F'].scatter(time2027,net_stars_obs_wbulge,color='r',marker='^')
    axs['F'].set_xlabel(f"Time after {ts[0].value} (days)",fontsize=10)
    axs['F'].set_ylabel("Number of Reference Stars",fontsize=14)
    axs['F'].set_xlim([np.min(time2027),np.max(time2027)])

    #SortedRefs = RefStarsNominal.sort_values(by=['ObsDays'],ascending=False)
    SortedRefs = RefStarsNominal.sort_values(by=['ObsDays_wBulge'],ascending=False)
    print('Most Observable Reference Stars with Science Target '+sciname)
    #print(SortedRefs[["main_id","ObsDays"]])
    print(SortedRefs[["main_id","ObsDays","ObsDays_wBulge"]])

    #fig1.tight_layout()
    if save == True:
        sciname = sciname.replace("*","")
        ranklist = "".join(ranks)
        fig1.savefig(savedir+"/SciObs_"+sciname.replace(" ","")+"_Ranks"+ranklist+"_delPitch_"+str(delpitch).replace(".","_")+".jpg")
        delta_pitchDF.to_csv(savedir+"/SciObs_"+sciname.replace(" ","")+"_Ranks"+ranklist+"_delPitch_"+str(delpitch).replace(".","_")+".csv",index=False)


    plt.show()

# %%
PitchfromRefCatalog_Mod('pi Men',ranks = ['A','B'],delpitch=5.0)
# Out:
# Selected reference stars:
# ['* kap Ori' '* bet CMa' '* bet Leo' '* bet Car' '* eps Ori' '* del Cas'
#  '* alf Ara' '* eta Cen' '* rho Pup' '* eta UMa' '* gam Ori' '* alf Cyg'
#  '* bet Lup' '* alf Lep' '* del Leo' '* bet UMa' '* eta CMa' '* alf Cep'
#  '* gam TrA' '* eps CMa' '* alf Col' '* bet TrA' '* alf Gru' '* bet CMi']
# /Users/jrhom/anaconda3/envs/Disk_ETCsSep24/lib/python3.11/site-packages/erfa/core.py:133: ErfaWarning: ERFA function "pmsafe" yielded 365 of "distance overridden (Note 6)"
#   warn(f'ERFA function "{func_name}" yielded {wmsg}', ErfaWarning)
# 19 days of general and < 5.0 degree Delta pitch angle observability with * kap Ori
# 0 days of general and < 5.0 degree Delta pitch angle observability with * kap Ori and not conflicting with bulge
# 20 days of general and < 5.0 degree Delta pitch angle observability with * bet CMa
# 0 days of general and < 5.0 degree Delta pitch angle observability with * bet CMa and not conflicting with bulge
# 18 days of general and < 5.0 degree Delta pitch angle observability with * bet Leo
# 18 days of general and < 5.0 degree Delta pitch angle observability with * bet Leo and not conflicting with bulge
# 70 days of general and < 5.0 degree Delta pitch angle observability with * bet Car
# 70 days of general and < 5.0 degree Delta pitch angle observability with * bet Car and not conflicting with bulge
# 17 days of general and < 5.0 degree Delta pitch angle observability with * eps Ori
# 0 days of general and < 5.0 degree Delta pitch angle observability with * eps Ori and not conflicting with bulge
# 22 days of general and < 5.0 degree Delta pitch angle observability with * del Cas
# 0 days of general and < 5.0 degree Delta pitch angle observability with * del Cas and not conflicting with bulge
# 30 days of general and < 5.0 degree Delta pitch angle observability with * alf Ara
# 0 days of general and < 5.0 degree Delta pitch angle observability with * alf Ara and not conflicting with bulge
# 27 days of general and < 5.0 degree Delta pitch angle observability with * eta Cen
# 27 days of general and < 5.0 degree Delta pitch angle observability with * eta Cen and not conflicting with bulge
# 22 days of general and < 5.0 degree Delta pitch angle observability with * rho Pup
# 10 days of general and < 5.0 degree Delta pitch angle observability with * rho Pup and not conflicting with bulge
# 31 days of general and < 5.0 degree Delta pitch angle observability with * eta UMa
# 31 days of general and < 5.0 degree Delta pitch angle observability with * eta UMa and not conflicting with bulge
# 17 days of general and < 5.0 degree Delta pitch angle observability with * gam Ori
# 0 days of general and < 5.0 degree Delta pitch angle observability with * gam Ori and not conflicting with bulge
# 46 days of general and < 5.0 degree Delta pitch angle observability with * alf Cyg
# 46 days of general and < 5.0 degree Delta pitch angle observability with * alf Cyg and not conflicting with bulge
# 27 days of general and < 5.0 degree Delta pitch angle observability with * bet Lup
# 27 days of general and < 5.0 degree Delta pitch angle observability with * bet Lup and not conflicting with bulge
# 20 days of general and < 5.0 degree Delta pitch angle observability with * alf Lep
# 0 days of general and < 5.0 degree Delta pitch angle observability with * alf Lep and not conflicting with bulge
# 18 days of general and < 5.0 degree Delta pitch angle observability with * del Leo
# 18 days of general and < 5.0 degree Delta pitch angle observability with * del Leo and not conflicting with bulge
# 22 days of general and < 5.0 degree Delta pitch angle observability with * bet UMa
# 22 days of general and < 5.0 degree Delta pitch angle observability with * bet UMa and not conflicting with bulge
# 24 days of general and < 5.0 degree Delta pitch angle observability with * eta CMa
# 0 days of general and < 5.0 degree Delta pitch angle observability with * eta CMa and not conflicting with bulge
# 44 days of general and < 5.0 degree Delta pitch angle observability with * alf Cep
# 37 days of general and < 5.0 degree Delta pitch angle observability with * alf Cep and not conflicting with bulge
# 43 days of general and < 5.0 degree Delta pitch angle observability with * gam TrA
# 10 days of general and < 5.0 degree Delta pitch angle observability with * gam TrA and not conflicting with bulge
# 24 days of general and < 5.0 degree Delta pitch angle observability with * eps CMa
# 0 days of general and < 5.0 degree Delta pitch angle observability with * eps CMa and not conflicting with bulge
# 26 days of general and < 5.0 degree Delta pitch angle observability with * alf Col
# 0 days of general and < 5.0 degree Delta pitch angle observability with * alf Col and not conflicting with bulge
# 37 days of general and < 5.0 degree Delta pitch angle observability with * bet TrA
# 0 days of general and < 5.0 degree Delta pitch angle observability with * bet TrA and not conflicting with bulge
# 29 days of general and < 5.0 degree Delta pitch angle observability with * alf Gru
# 29 days of general and < 5.0 degree Delta pitch angle observability with * alf Gru and not conflicting with bulge
# 17 days of general and < 5.0 degree Delta pitch angle observability with * bet CMi
# 0 days of general and < 5.0 degree Delta pitch angle observability with * bet CMi and not conflicting with bulge
# 310 days of general and < 5.0 degree Delta pitch angle observability with any available ref
# 171 days of general and < 5.0 degree Delta pitch angle observability with any available ref and not during bulge
# Most Observable Reference Stars with Science Target pi Men
#       main_id  ObsDays  ObsDays_wBulge
# 3   * bet Car     70.0            70.0
# 11  * alf Cyg     46.0            46.0
# 17  * alf Cep     44.0            37.0
# 9   * eta UMa     31.0            31.0
# 22  * alf Gru     29.0            29.0
# 12  * bet Lup     27.0            27.0
# 7   * eta Cen     27.0            27.0
# 15  * bet UMa     22.0            22.0
# 2   * bet Leo     18.0            18.0
# 14  * del Leo     18.0            18.0
# 8   * rho Pup     22.0            10.0
# 18  * gam TrA     43.0            10.0
# 16  * eta CMa     24.0             0.0
# 21  * bet TrA     37.0             0.0
# 20  * alf Col     26.0             0.0
# 19  * eps CMa     24.0             0.0
# 0   * kap Ori     19.0             0.0
# 13  * alf Lep     20.0             0.0
# 1   * bet CMa     20.0             0.0
# 10  * gam Ori     17.0             0.0
# 6   * alf Ara     30.0             0.0
# 5   * del Cas     22.0             0.0
# 4   * eps Ori     17.0             0.0
# 23  * bet CMi     17.0             0.0
# /var/folders/_g/xxw7g6gs5yz0vfxg4s5nb12m0000gs/T/ipykernel_33080/2878640292.py:236: RuntimeWarning: All-NaN slice encountered
#   obs_absminpitch = np.nanmin(fullstackobs_pitch,axis=0)
# /var/folders/_g/xxw7g6gs5yz0vfxg4s5nb12m0000gs/T/ipykernel_33080/2878640292.py:237: RuntimeWarning: All-NaN slice encountered
#   obs_absminpitch_wbulge = np.nanmin(fullstackobs_pitch_wbulge,axis=0)
# /var/folders/_g/xxw7g6gs5yz0vfxg4s5nb12m0000gs/T/ipykernel_33080/2878640292.py:288: RuntimeWarning: All-NaN slice encountered
#   axs['E'].plot(np.nanmin(np.array(obsdates_actualobs),axis=0),np.nanmin(np.array(abs_pitch_actualobs),axis=0),marker='o',color='b')
# /var/folders/_g/xxw7g6gs5yz0vfxg4s5nb12m0000gs/T/ipykernel_33080/2878640292.py:289: RuntimeWarning: All-NaN slice encountered
#   axs['E'].plot(np.nanmin(np.array(obsdates_actualobs_wbulge),axis=0),np.nanmin(np.array(abs_pitch_actualobs_wbulge),axis=0),marker='^',color='r')
