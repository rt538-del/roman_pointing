# %% [markdown]
# # `roman_pointing` Google Colab Setup
#
# This notebook sets up `roman_pointing` for use with Google Colab.  It needs to be run **once**. If you are running `roman_pointing` from a local installation, you do **not** need to execute anything in this notebook.

# %% [markdown]
# ## Google Colab Usage
#
# **Confirm login account**
# * Please make sure to be logged in with the Google account you want to use for the exercises before running the code cells below. You can check by clicking the circular account icon in the top right corner of the colab notebook.
#
# **Working directory**
# * Note: The software and data will be installed in a directory called "roman_pointing" in your Google drive. This directory will be created if it does not exist. At any point, you may remove this directory entirely from your Google drive and re-run this Notebook to get a fresh installation of `roman_pointing`.
#
# **Running cells**
# * Run cells individually by clicking on the triangle on each cell or click 'Run all' from the top of the screen or from the 'Runtime' menu
#
# **To Restart runtime**
# *   Click on Runtime menu item
# *   Select Restart session
# *   Select Run code cells individually from the top
#
# **To Recreate runtime**
# *   Click on Runtime menu item
# *   Select Disconnect and Delete runtime
# *   Select Run code cells individually from the top
#
# **To Exit:**
# *   Close the browser window

# %% [markdown]
# ## Setup Google Drive directory and download data
#
# #### Run the next cell to mount the Google Drive
#
# You will receive some or all of the following prompts:
#
# * Warning: This notebook was not authored by Google - Click "Run Anyway"
# * Permit this notebook to access your Google Drive files? - Click "Connect to Google Drive"
# * A new browser window will prompt you to select an account and authorize access
#   * Select the Google account you wish to use and click Continue on each subsequent screen until the dialog vanishes
#
# Upon completion of cell execution, you should see `Mounted at /content/drive`

# %%
from google.colab import drive
drive.mount("/content/drive")

# %% [markdown]
# #### Run the next cell to create the roman_pointing directory and download the code onto Google Drive

# %%
# Create the directory
import os
# Ensure repository is downloaded and up to date 
drive_dir = "/content/drive/MyDrive/"
top_path = os.path.join(drive_dir, "roman_pointing")
repo_path = os.path.join(top_path, "roman_pointing")
os.makedirs(repo_path, exist_ok = True)
if not os.path.exists(repo_path):
  os.chdir(top_path)
  # !git clone --depth 1 https://github.com/roman-corgi/roman_pointing
else:
  os.chdir(repo_path)
  # !git pull

# %% [markdown]
# After successful execution of the last cell, you should see output including `Cloning into 'roman_pointing'` along with additional messages indicating download progress. If the repo already exists, you might see `Already up to date.`

# %% [markdown]
# If you have reached this point without errors, you are ready to start using `roman_pointing` with Google Colab.
#
# Click on the `File` menu (at the top left of the page) and select `Open Notebook`. Select `GitHub` in the left-hand pane of the dialog that appears, make sure that `roman-corgi` is entered in the top text box and select the `roman-corgi/roman_pointing` repository from the dropdown menu.  A list of all available notebooks should appear. You may see a `Leave Page` (or equivalent) prompt - it is okay to proceed.
#
# If you encountered any errors while executing this notebook, please re-check the instructions carefully, and if you need further support, create an issue here: https://github.com/roman-corgi/roman_pointing/issues
