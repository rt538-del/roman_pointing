# %% [markdown]
# ### Roman Observatory Coronagraphic Instrument Reference Star Picker
#
# This version of the tool is intended for use with Google Colab.  To run the offline tool, use Notebook Reference_Star_Picker.ipynb.

# %%
# %%capture
import os
from google.colab import drive
drive.mount('/content/drive')

# Go to roman_pointing repository, update and install
drive_dir = "/content/drive/MyDrive/"
rp_path = os.path.join(drive_dir, "roman_pointing", "roman_pointing")
notebooks_path = os.path.join(rp_path, "Notebooks")
os.chdir(rp_path)
# !git pull
# !pip install .

# Refresh package list to pick up new installations
import site
site.main()

# Change to the Notebooks directory
os.chdir(notebooks_path)

# import widget
from roman_pointing.Reference_Star_UI import ReferenceStarPickerUI
ui = ReferenceStarPickerUI()

# %%
# run widget
ui.display()
